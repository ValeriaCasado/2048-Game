# %%
import numpy as np
import random
from scipy import ndimage, misc
import copy
import time
from deap import base
from deap import creator
from deap import tools
import game
import pandas as pd

# %%
a = pd.read_csv("collected_data/GArun.txt", sep= " ")
a.head()
# Out:
#    iteration   best         avg  highestnumber
# 0          0  396.0  276.133333             32
# 1          1  396.0  282.933333             32
# 2          2  484.0  304.533333             64
# 3          3  484.0  337.066667             64
# 4          4  484.0  386.933333             64

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')

plt.xlabel("Generations")
plt.ylabel("Fitness")
plt.plot(np.array(a.best), label="Best Individual Fitness")
plt.plot(np.array(a.avg), label="Average Fitness")
plt.legend()

# %%
a = pd.read_csv("collected_data/average_move_times.txt", sep= " ")
abs(sum(a.times)/len(a.times))
# Out:
# 0.0009440288427245392
